# %%
#CBOW给一段文本，选择一定的窗口，然后利用上下文预测中间目标词
#skipgram  中间词预测上下文

# %%
#Fasttext实现word2vec的训练和使用
#获取训练数据
import fasttext
def dm():
    #无监督模式训练词向量
    mymodel = fasttext.train_unsupervised('./enwik9')
    print("训练向量ok")
    #保存
    mymodel.save.model('./file9.bin')
#执行
dm()
