# %%
#RNN模型
#- 定义：
#- 循环神经网络：当前时间步的输出：当前时间步的输入+上一时间步的隐层输出
#文本翻译、文本分类等等

# %%
#- 根据输入与输出结构
 # - N vs N 
#    - 特点：输入和输出是等长的
 #   - 范围：诗歌、对联
 # - N vs 1
 #   - 特点：输入不限定长度，输出是唯一的
 #   - 范围：分类任务
 # - 1 vs N
  #  - 特点：输入是唯一的，输出不限定长度
  #  - 范围：图片生成任务
 # - N vs M（seq2seq架构）
  #  - 特点：输入和输出不等长
 #   - 范围：文本翻译任务等
#- 根据RNN内部结构
 # - 传统RNN
  #- LSTM
 # - Bi-LSTM
 # - GRU
 # - Bi-GRU
